# %%
import pandas as pandas
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# %%
df=pandas.read_csv('features.csv')
print(df.head())
# Out:
#                                           video_path label  ...  feat_142  feat_143
# 0  C:\ai-video-lbp-svm\data\sdfvd2.0\real\real_v1...  real  ...  0.006185  0.002861
# 1  C:\ai-video-lbp-svm\data\sdfvd2.0\real\real_v1...  real  ...  0.061320  0.005516
# 2  C:\ai-video-lbp-svm\data\sdfvd2.0\real\real_v1...  real  ...  0.036243  0.004045
# 3  C:\ai-video-lbp-svm\data\sdfvd2.0\real\real_v1...  real  ...  0.020975  0.003415
# 4  C:\ai-video-lbp-svm\data\sdfvd2.0\real\real_v1...  real  ...  0.037554  0.004041
#
# [5 rows x 147 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 927 entries, 0 to 926
# Columns: 147 entries, video_path to feat_143
# dtypes: float64(144), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
X = df.drop(['label', 'video_path'], axis=1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
print(X)
# Out:
#      frames_used    feat_0    feat_1  ...  feat_141  feat_142  feat_143
# 0            109  0.008673  0.010103  ...  0.000863  0.006185  0.002861
# 1            109  0.004321  0.005521  ...  0.001068  0.061320  0.005516
# 2            109  0.004417  0.005576  ...  0.000942  0.036243  0.004045
# 3            109  0.004841  0.005988  ...  0.000958  0.020975  0.003415
# 4            109  0.004723  0.005892  ...  0.001493  0.037554  0.004041
# ..           ...       ...       ...  ...       ...       ...       ...
# 922          110  0.009316  0.010965  ...  0.001227  0.027146  0.003469
# 923           81  0.002586  0.005523  ...  0.001310  0.005846  0.009644
# 924           94  0.002504  0.001349  ...  0.000544  0.004942  0.002167
# 925           79  0.004791  0.006651  ...  0.003160  0.169929  0.005096
# 926          115  0.008283  0.009508  ...  0.002025  0.030074  0.005660
#
# [927 rows x 145 columns]

# %%
model = SVC(kernel='linear')

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     not_real       0.73      0.81      0.77        86
#         real       0.82      0.74      0.78       100
#
#     accuracy                           0.77       186
#    macro avg       0.78      0.78      0.77       186
# weighted avg       0.78      0.77      0.77       186
